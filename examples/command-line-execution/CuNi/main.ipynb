# %% [markdown]
# # COMMAND LINE EXAMPLE

# %%
# !HopDec.py Minimize input/IV1.dat IV1_Min.dat
# Out:
# ####################################################################################################
# ########################################## Hop + Decorate ##########################################
# ####################################################################################################
# [25/03/25, 08:53:37]: HopDec >> Running: Minimize
# [25/03/25, 08:53:37]:   Lammps >> Minimizing. F Tol: 1e-05.
# [25/03/25, 08:53:37]: Lammps >> Completed Minimization, E: -899.4873 eV
# [25/03/25, 08:53:37]:     Minimize >> Minimized state is stored at: IV1_Min.dat
# [25/03/25, 08:53:37]: HopDec >> Finishing: Minimize
# ####################################################################################################
# ############################################### Fin. ###############################################
# ####################################################################################################

# %%
# !HopDec.py Dimer IV1_Min.dat IV2.dat -d -m -p
# Out:
# ####################################################################################################
# ########################################## Hop + Decorate ##########################################
# ####################################################################################################
# [25/03/25, 08:53:38]: HopDec >> Running: Dimer
# [25/03/25, 08:53:38]:   Lammps >> Minimizing. F Tol: 1e-05.
# [25/03/25, 08:53:38]: Lammps >> Completed Minimization, E: -899.4873 eV
# [25/03/25, 08:53:38]: Dimer >> Found saddle point, 0.6377232577303857 eV above inital position
# [25/03/25, 08:53:38]: Dimer >> Pushing saddle point into new minima
# [25/03/25, 08:53:38]:   Lammps >> Minimizing. F Tol: 1e-05.
# [25/03/25, 08:53:38]: Lammps >> Completed Minimization, E: -899.4873 eV
# [25/03/25, 08:53:38]: Dimer >> Writing file to IV2.dat
# [25/03/25, 08:53:38]: HopDec >> Finishing: Dimer
# ####################################################################################################
# ############################################### Fin. ###############################################
# ####################################################################################################

# %%
# !HopDec.py Minimize IV2.dat IV2_Min.dat
# Out:
# ####################################################################################################
# ########################################## Hop + Decorate ##########################################
# ####################################################################################################
# [25/03/25, 08:53:40]: HopDec >> Running: Minimize
# [25/03/25, 08:53:40]:   Lammps >> Minimizing. F Tol: 1e-05.
# [25/03/25, 08:53:40]: Lammps >> Completed Minimization, E: -899.4873 eV
# [25/03/25, 08:53:40]:     Minimize >> Minimized state is stored at: IV2_Min.dat
# [25/03/25, 08:53:40]: HopDec >> Finishing: Minimize
# ####################################################################################################
# ############################################### Fin. ###############################################
# ####################################################################################################

# %%
# !HopDec.py NEB IV1_Min.dat IV2_Min.dat -p
# Out:
# ####################################################################################################
# ########################################## Hop + Decorate ##########################################
# ####################################################################################################
# [25/03/25, 08:53:41]: HopDec >> Running: NEB
# [25/03/25, 08:53:41]: NEB >> Minimizing End Points
# [25/03/25, 08:53:41]:   Lammps >> Minimizing. F Tol: 1e-05.
# [25/03/25, 08:53:41]: Lammps >> Completed Minimization, E: -899.4873 eV
# [25/03/25, 08:53:41]:   Lammps >> Minimizing. F Tol: 1e-05.
# [25/03/25, 08:53:41]: Lammps >> Completed Minimization, E: -899.4873 eV
# [25/03/25, 08:53:41]: NEB >> WARNING. Initial and Final Structures are the Same. Skipping...
# [25/03/25, 08:53:41]: NEB >> Completed 0 NEBs!
# [25/03/25, 08:53:41]: HopDec >> Finishing: NEB
# ####################################################################################################
# ############################################### Fin. ###############################################
# ####################################################################################################
